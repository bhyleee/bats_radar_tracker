# %%
# from azureml.core.environment import Environment
# Environment(name="dopplerenv")

# # Check core SDK version number
# import azureml.core

# print("SDK version:", azureml.core.VERSION)

# from azureml.core import Workspace

# ws = Workspace.from_config()

# # # Storage management
# # Create Datastore
# from azureml.core.datastore import Datastore

# doppler_blob = Datastore.register_azure_blob_container(ws, 
#                       datastore_name="doppler_scenes", 
#                       container_name="sampledata", 
#                       account_name="pipelinedata", 
#                       overwrite=True)

# def_data_store = ws.get_default_datastore()

# # Create data objects
# from azureml.core.dataset import Dataset
# from azureml.pipeline.core import PipelineData

# input_images = Dataset.File.from_files((doppler_blob, "doppler/images/"))
# label_ds = Dataset.File.from_files((doppler_blob, "doppler/labels/"))
# output_dir = PipelineData(name="scenes", datastore=def_data_store)

# # Register the dataset
# input_images = input_images.register(workspace=ws, name="input_images")
# label_ds = label_ds.register(workspace=ws, name="label_ds", create_new_version=True)

# %%
import subprocess
import sys

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# install('rasterio')
# install('pyshp')
# install('nexradaws')
# install('shapely')
# install('arm_pyart')
# install('netcdf4')

# %%
# %matplotlib inline
import tempfile
import pytz
import cartopy
import os
os.environ['PROJ_LIB'] = r'/anaconda/envs/dopplerenv/share/proj'
# os.environ['GDAL_DATA'] = r'/anaconda/envs/dopplerenv/lib/python3.8/site-packages/gdal'
# from mpl_toolkits.basemap import Basemap
import os 
import pyart
import nexradaws
import numpy as np
from osgeo import gdal
from time import time
import matplotlib.pyplot as plt
import glob
from datetime import datetime, date, timedelta
import pathlib
import rasterio as rio
import shutil
# from sklearn.preprocessing import MinMaxScaler
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:10: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _nlv = LooseVersion(_np_version)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_under1p16 = _nlv < LooseVersion("1.16")
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:12: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_under1p17 = _nlv < LooseVersion("1.17")
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:13: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_under1p18 = _nlv < LooseVersion("1.18")
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:14: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_under1p19 = _nlv < LooseVersion("1.19")
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py:15: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_under1p20 = _nlv < LooseVersion("1.20")
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/function.py:125: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(_np_version) >= LooseVersion("1.17.0"):
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/pandas/compat/numpy/function.py:125: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(_np_version) >= LooseVersion("1.17.0"):
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/xarray/core/dask_array_compat.py:61: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(dask_version) > LooseVersion("2.9.0"):
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/xarray/core/dask_array_compat.py:61: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(dask_version) > LooseVersion("2.9.0"):
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/xarray/core/pdcompat.py:45: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(pd.__version__) < "0.25.0":
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/setuptools/_distutils/version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/matplotlib/__init__.py:182: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   a = distutils.version.LooseVersion(a)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/matplotlib/__init__.py:183: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   b = distutils.version.LooseVersion(b)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/matplotlib/__init__.py:182: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   a = distutils.version.LooseVersion(a)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/matplotlib/__init__.py:183: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   b = distutils.version.LooseVersion(b)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/matplotlib/__init__.py:182: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   a = distutils.version.LooseVersion(a)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/matplotlib/__init__.py:183: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   b = distutils.version.LooseVersion(b)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/mpl_toolkits/basemap/__init__.py:33: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _matplotlib_version = LooseVersion(_matplotlib_version)
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/mpl_toolkits/basemap/__init__.py:34: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _mpl_required_version = LooseVersion('0.98')
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/botocore/httpsession.py:17: DeprecationWarning: 'urllib3.contrib.pyopenssl' module is deprecated and will be removed in a future release of urllib3 2.x. Read more in this issue: https://github.com/urllib3/urllib3/issues/2680
#   from urllib3.contrib.pyopenssl import orig_util_SSLContext as SSLContext

# %%
def create_date_directories(single_date):
    
    # Create date directory
    DATEDIR = pathlib.Path(os.getcwd() + '/' + str(single_date))
    DATEDIR.mkdir(parents=True, exist_ok=True)
    RAWDIR = pathlib.Path(os.getcwd() + '/' + str(single_date) + '/1_raw/')
    RAWDIR.mkdir(parents=True, exist_ok=True)
    AGGSCANDIR = pathlib.Path(os.getcwd() + '/' + str(single_date) + '/2_scan_agg/')
    AGGSCANDIR.mkdir(parents=True, exist_ok=True)
    AGGDIR = pathlib.Path(os.getcwd() + '/' + str(single_date) + '/3_daily_agg/')
    AGGDIR.mkdir(parents=True, exist_ok=True)

    return DATEDIR, RAWDIR, AGGSCANDIR, AGGDIR
    
def return_daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

def download_raw(start_date, tower, time_zone):
    
    start_date = start_date.strftime("%Y%m%d")
    start_time = '1800'
    startdatetime = "".join((start_date, start_time))
    start_date1 = datetime.strptime(startdatetime, "%Y%m%d%H%M")
    
    #download entire evening's worth of data
    end_date = start_date1 + timedelta(hours=3)
    
    conn = nexradaws.NexradAwsInterface()
    # Download data
    central_timezone = pytz.timezone(time_zone)
    radar_id = tower
    start = central_timezone.localize(start_date1)
    end = central_timezone.localize(end_date)
    scans = conn.get_avail_scans_in_range(start, end, radar_id)
    # print("There are {} scans available between {} and {}\n".format(len(scans), start, end))

    results = conn.download(scans, templocation)

    # for scan in results.iter_success():
        # print ("{} volume scan time {}".format(scan.radar_id,scan.scan_time))
    
    return results
# Out:
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def download_reflectivity(scan, file, output_directory):
    
        ### Add reflectivity raster
        radar_reflect = scan.open_pyart()
        
        # mask out last 10 gates of each ray, this removes the "ring" around th radar.
        radar_reflect.fields['reflectivity']['data'][:, -10:] = np.ma.masked

        # exclude masked gates from the gridding
        gatefilter_reflect = pyart.filters.GateFilter(radar_reflect)
        gatefilter_reflect.exclude_transition()
        gatefilter_reflect.exclude_masked('reflectivity')
        grid_reflect = pyart.map.grid_from_radars(
            radar_reflect, 
            gatefilters=(gatefilter_reflect, ),
            grid_shape=(1, 2000, 2000),
            grid_limits=((0, 1500.0),(-70000, 70000), (-70000, 70000)),
            fields=['reflectivity'],
            gridding_algo="map_gates_to_grid",
            weighting_function='NEAREST',
            roi_func='constant_roi', constant_roi=2000.0)

        output_path = os.path.join(str(output_directory) + '/' + str(file) + '_reflectivity.tif')
        
        output_file = pyart.io.write_grid_geotiff(grid_reflect, output_path, 'reflectivity', rgb=False, warp=True, 
                                cmap='pyart_NWSRef', vmin=0, vmax=100, level=0)
        return output_file
        
def download_velocity(scan, file, output_directory):
    
        ### Add velocity raster
        radar_velocity = scan.open_pyart()
        
        # mask out last 10 gates of each ray, this removes the "ring" around th radar.
        radar_velocity.fields['velocity']['data'][:, -10:] = np.ma.masked

        # exclude masked gates from the gridding
        gatefilter_velocity = pyart.filters.GateFilter(radar_velocity)
        gatefilter_velocity.exclude_transition()
        gatefilter_velocity.exclude_masked('velocity')
        grid_velocity = pyart.map.grid_from_radars(
            radar_velocity, 
            gatefilters=(gatefilter_velocity, ),
            grid_shape=(1, 2000, 2000),
            grid_limits=((0, 1500.0),(-70000, 70000), (-70000, 70000)),
            fields=['velocity'],
            roi_func='constant_roi', constant_roi=2000.0, weighting_function='Nearest')
        
        output_path = os.path.join(str(output_directory) + '/' + str(file) + '_velocity.tif')

        output_file = pyart.io.write_grid_geotiff(grid_velocity, output_path, 'velocity', rgb=False, warp=True, 
                                cmap='pyart_NWSRef', vmin=-70, vmax=70, level=0)
        
        return output_file
    
def download_differential_phase(scan, file, output_directory):
    
         ### Add differential phase raster     
        radar_differential_phase = scan.open_pyart()
        
        # mask out last 10 gates of each ray, this removes the "ring" around th radar.
        radar_differential_phase.fields['differential_phase']['data'][:, -10:] = np.ma.masked

        # exclude masked gates from the gridding
        gatefilter_differential_phase = pyart.filters.GateFilter(radar_differential_phase)
        gatefilter_differential_phase.exclude_transition()
        gatefilter_differential_phase.exclude_masked('differential_phase')
        grid_differential_phase = pyart.map.grid_from_radars(
            radar_differential_phase, 
            gatefilters=(gatefilter_differential_phase, ),
            grid_shape=(1, 2000, 2000),
            grid_limits=((0, 1500.0),(-70000, 70000), (-70000, 70000)),
            fields=['differential_phase'],
            roi_func='constant_roi', constant_roi=2000.0, weighting_function='Nearest')
        
        output_path = os.path.join(str(output_directory) + '/' + str(file) + '_differential_phase.tif')
        
        output_file = pyart.io.write_grid_geotiff(grid_differential_phase, output_path, 'differential_phase', rgb=False, warp=True, 
                                cmap='pyart_NWSRef', vmin=-10, vmax=150, level=0)
        
        return output_file
  
def download_differential_reflectivity(scan, file, output_directory):
    
        ### Add differential reflectivity raster        
        radar_differential_reflectivity = scan.open_pyart()
        
        # mask out last 10 gates of each ray, this removes the "ring" around th radar.
        radar_differential_reflectivity.fields['differential_reflectivity']['data'][:, -10:] = np.ma.masked

        # exclude masked gates from the gridding
        gatefilter_differential_reflectivity = pyart.filters.GateFilter(radar_differential_reflectivity)
        gatefilter_differential_reflectivity.exclude_transition()
        gatefilter_differential_reflectivity.exclude_masked('differential_reflectivity')
        grid_differential_reflectivity = pyart.map.grid_from_radars(
            radar_differential_reflectivity, 
            gatefilters=(gatefilter_differential_reflectivity, ),
            grid_shape=(1, 2000, 2000),
            grid_limits=((0, 1500.0),(-70000, 70000), (-70000, 70000)),
            fields=['differential_reflectivity'],
            roi_func='constant_roi', constant_roi=2000.0, weighting_function='Nearest')
        
        output_path = os.path.join(str(output_directory) + '/' + str(file) + '_differential_reflectivity.tif')
        
        output_file = pyart.io.write_grid_geotiff(grid_differential_reflectivity, output_path, 'differential_reflectivity', rgb=False, warp=True, 
                                cmap='pyart_NWSRef', vmin=-20, vmax=20, level=0)
        
def download_cross_correlation(scan, file, output_directory):
    
        ### Add cross correlation raster
        radar_cross_correlation_ratio = scan.open_pyart()
        
        # mask out last 10 gates of each ray, this removes the "ring" around th radar.
        radar_cross_correlation_ratio.fields['cross_correlation_ratio']['data'][:, -10:] = np.ma.masked

        # exclude masked gates from the gridding
        gatefilter_cross_correlation_ratio = pyart.filters.GateFilter(radar_cross_correlation_ratio)
        gatefilter_cross_correlation_ratio.exclude_transition()
        gatefilter_cross_correlation_ratio.exclude_masked('cross_correlation_ratio')
        grid_cross_correlation_ratio = pyart.map.grid_from_radars(
            radar_cross_correlation_ratio, 
            gatefilters=(gatefilter_cross_correlation_ratio, ),
            grid_shape=(1, 2000, 2000),
            grid_limits=((0, 1500.0),(-70000, 70000), (-70000, 70000)),
            fields=['cross_correlation_ratio'],
            roi_func='constant_roi', constant_roi=2000.0, weighting_function='Nearest')
        
        output_path = os.path.join(str(output_directory) + '/' + str(file) + '_cross_correlation_ratio.tif')
        
        output_file = pyart.io.write_grid_geotiff(grid_cross_correlation_ratio, output_path, 'cross_correlation_ratio', rgb=False, warp=True, 
                                cmap='pyart_NWSRef', vmin=0, vmax=2, level=0)
        
        return output_file
    
def download_spectrum_width(scan, file, output_directory):
    
        ### Add spectrum width raster
        radar_spectrum_width = scan.open_pyart()
        
        # mask out last 10 gates of each ray, this removes the "ring" around th radar.
        radar_spectrum_width.fields['spectrum_width']['data'][:, -10:] = np.ma.masked

        # exclude masked gates from the gridding
        gatefilter_spectrum_width = pyart.filters.GateFilter(radar_spectrum_width)
        gatefilter_spectrum_width.exclude_transition()
        gatefilter_spectrum_width.exclude_masked('spectrum_width')
        grid_spectrum_width = pyart.map.grid_from_radars(
            radar_spectrum_width, 
            gatefilters=(gatefilter_spectrum_width, ),
            grid_shape=(1, 2000, 2000),
            grid_limits=((0, 15000.0),(-70000, 70000), (-70000, 70000)),
            fields=['spectrum_width'],
            roi_func='constant_roi', constant_roi=2000.0, weighting_function='Nearest')
        
        output_path = os.path.join(str(output_directory) + '/' + str(file) + '_spectrum_width.tif')
        
        output_file = pyart.io.write_grid_geotiff(grid_spectrum_width, output_path, 'spectrum_width', rgb=False, warp=True, 
                                cmap='pyart_NWSRef', vmin=0, vmax=20, level=0)
        
        return output_file
# Out:
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
os.chdir(os.path.expanduser('../data/training/sources/validation_data/tx'))
os.getcwd()
# Out:
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '/Users/brianlee/Desktop/new_bats/data/training/sources/validation_data/tx'

# %%
# # Establish place
# SCRIPTSDIR = os.getcwd()

# # Change to datastorage?
# os.chdir('../data')
DATADIR = os.getcwd()

# Define start and end dates
start_date = date(2017, 8, 5)
end_date = date(2017, 8, 10)

# Define current date
current_date = datetime.today().strftime('%Y%m%d')

# Create general data directories
pathlib.Path(DATADIR + '/doppler/' + str(current_date)).mkdir(parents=True, exist_ok=True)
pathlib.Path(DATADIR + '/doppler/' + str(current_date) + '/' + str(start_date.strftime('%Y'))).mkdir(parents=True, exist_ok=True)

os.chdir(DATADIR + '/doppler/' + str(current_date) + '/' + str(start_date.strftime('%Y')))
             
YEARDIR = os.getcwd()
             
# Loop through individual dates, create directories, and apply functions.
for single_date in return_daterange(start_date, end_date):
    DATEDIR, RAWDIR, AGGSCANDIR, AGGDIR = create_date_directories(single_date.strftime("%Y%m%d"))
    # print(RAWDIR)
    
    # Make temp directory and close when done
    templocation = tempfile.mkdtemp()
    results = download_raw(single_date, 'KEWX', 'US/Pacific')
    
    for i,scan in enumerate(results.iter_success(),start=1):
        file = scan.scan_time.strftime('%Y%m%d_%H%M')
        try:
            download_reflectivity(scan, file, RAWDIR)
            download_velocity(scan, file, RAWDIR)
            download_differential_phase(scan, file, RAWDIR)
            download_differential_reflectivity(scan, file, RAWDIR)
            download_cross_correlation(scan, file, RAWDIR)
            download_spectrum_width(scan, file, RAWDIR)
            print(file)

            os.chdir(RAWDIR)

            file_list = []

            for i in os.listdir(RAWDIR):

                # match scenes from same time and combine in file.
                if os.path.isfile(os.path.join(RAWDIR,i)) and str(file) in i:
                    file_list.append(i)
            file_list.sort()
            print(file_list)


            # Read metadata of first file
            with rio.open(file_list[0]) as src0:
                meta = src0.meta

            # print('read metadata')

            # Update meta to reflect the number of layers
            meta.update(count = len(file_list))

            # print('updated metadata')
            print(file_list)

            # Read each layer and write it to stack
            with rio.open(os.path.join(str(AGGSCANDIR) + '/' + str(file) + '.tif'), 'w', **meta) as dst:
                for id, layer in enumerate(file_list, start=1):
                    # print(layer)
                    with rio.open(layer) as src1:
                        dst.write_band(id, src1.read(1))

            # file.close()

        except:
            print(file + ' did not work')
            # file.close()

    shutil.rmtree(templocation)
    
    os.chdir(YEARDIR)
    # templocation.cleanup()
# Out:
# /Users/brianlee/opt/anaconda3/envs/doppler/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Downloaded KEWX20170806_010105_V06
# Downloaded KEWX20170806_010414_V06
# Downloaded KEWX20170806_011645_V06
# Downloaded KEWX20170806_010722_V06
# Downloaded KEWX20170806_011339_V06
# Downloaded KEWX20170806_011030_V06
# Downloaded KEWX20170806_012301_V06
# Downloaded KEWX20170806_011953_V06
# Downloaded KEWX20170806_013601_V06
# Downloaded KEWX20170806_012948_V06
# Downloaded KEWX20170806_012638_V06
# Downloaded KEWX20170806_013253_V06
# Downloaded KEWX20170806_014240_V06
# Downloaded KEWX20170806_014848_V06
# Downloaded KEWX20170806_014542_V06
# Downloaded KEWX20170806_013934_V06
# Downloaded KEWX20170806_015151_V06
# Downloaded KEWX20170806_015454_V06
# Downloaded KEWX20170806_015756_V06
# Downloaded KEWX20170806_020805_V06
# Downloaded KEWX20170806_020059_V06
# Downloaded KEWX20170806_020403_V06
# Downloaded KEWX20170806_021110_V06
# Downloaded KEWX20170806_022617_V06
# Downloaded KEWX20170806_022226_V06
# Downloaded KEWX20170806_021835_V06
# Downloaded KEWX20170806_023009_V06
# Downloaded KEWX20170806_021459_V06
# Downloaded KEWX20170806_023400_V06
# Downloaded KEWX20170806_023820_V06
# Downloaded KEWX20170806_024212_V06
# Downloaded KEWX20170806_024606_V06
# Downloaded KEWX20170806_025357_V06
# Downloaded KEWX20170806_025001_V06
# Downloaded KEWX20170806_025751_V06
# Downloaded KEWX20170806_030146_V06
# Downloaded KEWX20170806_030935_V06
# Downloaded KEWX20170806_032050_V06
# Downloaded KEWX20170806_031330_V06
# Downloaded KEWX20170806_030540_V06
# Downloaded KEWX20170806_031710_V06
# Downloaded KEWX20170806_032431_V06
# Downloaded KEWX20170806_033152_V06
# Downloaded KEWX20170806_033912_V06
# Downloaded KEWX20170806_032812_V06
# Downloaded KEWX20170806_033531_V06
# Downloaded KEWX20170806_034237_V06
# Downloaded KEWX20170806_034604_V06
# Downloaded KEWX20170806_034915_V06
# Downloaded KEWX20170806_035228_V06
# 50 out of 50 files downloaded...0 errors
# 20170806_0101
# ['20170806_0101_cross_correlation_ratio.tif', '20170806_0101_differential_phase.tif', '20170806_0101_differential_reflectivity.tif', '20170806_0101_reflectivity.tif', '20170806_0101_spectrum_width.tif', '20170806_0101_velocity.tif']
# ['20170806_0101_cross_correlation_ratio.tif', '20170806_0101_differential_phase.tif', '20170806_0101_differential_reflectivity.tif', '20170806_0101_reflectivity.tif', '20170806_0101_spectrum_width.tif', '20170806_0101_velocity.tif']
# 20170806_0104
# ['20170806_0104_cross_correlation_ratio.tif', '20170806_0104_differential_phase.tif', '20170806_0104_differential_reflectivity.tif', '20170806_0104_reflectivity.tif', '20170806_0104_spectrum_width.tif', '20170806_0104_velocity.tif']
# ['20170806_0104_cross_correlation_ratio.tif', '20170806_0104_differential_phase.tif', '20170806_0104_differential_reflectivity.tif', '20170806_0104_reflectivity.tif', '20170806_0104_spectrum_width.tif', '20170806_0104_velocity.tif']
# 20170806_0107
# ['20170806_0107_cross_correlation_ratio.tif', '20170806_0107_differential_phase.tif', '20170806_0107_differential_reflectivity.tif', '20170806_0107_reflectivity.tif', '20170806_0107_spectrum_width.tif', '20170806_0107_velocity.tif']
# ['20170806_0107_cross_correlation_ratio.tif', '20170806_0107_differential_phase.tif', '20170806_0107_differential_reflectivity.tif', '20170806_0107_reflectivity.tif', '20170806_0107_spectrum_width.tif', '20170806_0107_velocity.tif']
# 20170806_0110
# ['20170806_0110_cross_correlation_ratio.tif', '20170806_0110_differential_phase.tif', '20170806_0110_differential_reflectivity.tif', '20170806_0110_reflectivity.tif', '20170806_0110_spectrum_width.tif', '20170806_0110_velocity.tif']
# ['20170806_0110_cross_correlation_ratio.tif', '20170806_0110_differential_phase.tif', '20170806_0110_differential_reflectivity.tif', '20170806_0110_reflectivity.tif', '20170806_0110_spectrum_width.tif', '20170806_0110_velocity.tif']
# 20170806_0113
# ['20170806_0113_cross_correlation_ratio.tif', '20170806_0113_differential_phase.tif', '20170806_0113_differential_reflectivity.tif', '20170806_0113_reflectivity.tif', '20170806_0113_spectrum_width.tif', '20170806_0113_velocity.tif']
# ['20170806_0113_cross_correlation_ratio.tif', '20170806_0113_differential_phase.tif', '20170806_0113_differential_reflectivity.tif', '20170806_0113_reflectivity.tif', '20170806_0113_spectrum_width.tif', '20170806_0113_velocity.tif']
# 20170806_0116
# ['20170806_0116_cross_correlation_ratio.tif', '20170806_0116_differential_phase.tif', '20170806_0116_differential_reflectivity.tif', '20170806_0116_reflectivity.tif', '20170806_0116_spectrum_width.tif', '20170806_0116_velocity.tif']
# ['20170806_0116_cross_correlation_ratio.tif', '20170806_0116_differential_phase.tif', '20170806_0116_differential_reflectivity.tif', '20170806_0116_reflectivity.tif', '20170806_0116_spectrum_width.tif', '20170806_0116_velocity.tif']
# 20170806_0119
# ['20170806_0119_cross_correlation_ratio.tif', '20170806_0119_differential_phase.tif', '20170806_0119_differential_reflectivity.tif', '20170806_0119_reflectivity.tif', '20170806_0119_spectrum_width.tif', '20170806_0119_velocity.tif']
# ['20170806_0119_cross_correlation_ratio.tif', '20170806_0119_differential_phase.tif', '20170806_0119_differential_reflectivity.tif', '20170806_0119_reflectivity.tif', '20170806_0119_spectrum_width.tif', '20170806_0119_velocity.tif']
# 20170806_0123
# ['20170806_0123_cross_correlation_ratio.tif', '20170806_0123_differential_phase.tif', '20170806_0123_differential_reflectivity.tif', '20170806_0123_reflectivity.tif', '20170806_0123_spectrum_width.tif', '20170806_0123_velocity.tif']
# ['20170806_0123_cross_correlation_ratio.tif', '20170806_0123_differential_phase.tif', '20170806_0123_differential_reflectivity.tif', '20170806_0123_reflectivity.tif', '20170806_0123_spectrum_width.tif', '20170806_0123_velocity.tif']
# 20170806_0126
# ['20170806_0126_cross_correlation_ratio.tif', '20170806_0126_differential_phase.tif', '20170806_0126_differential_reflectivity.tif', '20170806_0126_reflectivity.tif', '20170806_0126_spectrum_width.tif', '20170806_0126_velocity.tif']
# ['20170806_0126_cross_correlation_ratio.tif', '20170806_0126_differential_phase.tif', '20170806_0126_differential_reflectivity.tif', '20170806_0126_reflectivity.tif', '20170806_0126_spectrum_width.tif', '20170806_0126_velocity.tif']
# 20170806_0129
# ['20170806_0129_cross_correlation_ratio.tif', '20170806_0129_differential_phase.tif', '20170806_0129_differential_reflectivity.tif', '20170806_0129_reflectivity.tif', '20170806_0129_spectrum_width.tif', '20170806_0129_velocity.tif']
# ['20170806_0129_cross_correlation_ratio.tif', '20170806_0129_differential_phase.tif', '20170806_0129_differential_reflectivity.tif', '20170806_0129_reflectivity.tif', '20170806_0129_spectrum_width.tif', '20170806_0129_velocity.tif']
# 20170806_0132
# ['20170806_0132_cross_correlation_ratio.tif', '20170806_0132_differential_phase.tif', '20170806_0132_differential_reflectivity.tif', '20170806_0132_reflectivity.tif', '20170806_0132_spectrum_width.tif', '20170806_0132_velocity.tif']
# ['20170806_0132_cross_correlation_ratio.tif', '20170806_0132_differential_phase.tif', '20170806_0132_differential_reflectivity.tif', '20170806_0132_reflectivity.tif', '20170806_0132_spectrum_width.tif', '20170806_0132_velocity.tif']
# 20170806_0136
# ['20170806_0136_cross_correlation_ratio.tif', '20170806_0136_differential_phase.tif', '20170806_0136_differential_reflectivity.tif', '20170806_0136_reflectivity.tif', '20170806_0136_spectrum_width.tif', '20170806_0136_velocity.tif']
# ['20170806_0136_cross_correlation_ratio.tif', '20170806_0136_differential_phase.tif', '20170806_0136_differential_reflectivity.tif', '20170806_0136_reflectivity.tif', '20170806_0136_spectrum_width.tif', '20170806_0136_velocity.tif']
# 20170806_0139
# ['20170806_0139_cross_correlation_ratio.tif', '20170806_0139_differential_phase.tif', '20170806_0139_differential_reflectivity.tif', '20170806_0139_reflectivity.tif', '20170806_0139_spectrum_width.tif', '20170806_0139_velocity.tif']
# ['20170806_0139_cross_correlation_ratio.tif', '20170806_0139_differential_phase.tif', '20170806_0139_differential_reflectivity.tif', '20170806_0139_reflectivity.tif', '20170806_0139_spectrum_width.tif', '20170806_0139_velocity.tif']
# 20170806_0142
# ['20170806_0142_cross_correlation_ratio.tif', '20170806_0142_differential_phase.tif', '20170806_0142_differential_reflectivity.tif', '20170806_0142_reflectivity.tif', '20170806_0142_spectrum_width.tif', '20170806_0142_velocity.tif']
# ['20170806_0142_cross_correlation_ratio.tif', '20170806_0142_differential_phase.tif', '20170806_0142_differential_reflectivity.tif', '20170806_0142_reflectivity.tif', '20170806_0142_spectrum_width.tif', '20170806_0142_velocity.tif']
# 20170806_0145
# ['20170806_0145_cross_correlation_ratio.tif', '20170806_0145_differential_phase.tif', '20170806_0145_differential_reflectivity.tif', '20170806_0145_reflectivity.tif', '20170806_0145_spectrum_width.tif', '20170806_0145_velocity.tif']
# ['20170806_0145_cross_correlation_ratio.tif', '20170806_0145_differential_phase.tif', '20170806_0145_differential_reflectivity.tif', '20170806_0145_reflectivity.tif', '20170806_0145_spectrum_width.tif', '20170806_0145_velocity.tif']
# 20170806_0148
# ['20170806_0148_cross_correlation_ratio.tif', '20170806_0148_differential_phase.tif', '20170806_0148_differential_reflectivity.tif', '20170806_0148_reflectivity.tif', '20170806_0148_spectrum_width.tif', '20170806_0148_velocity.tif']
# ['20170806_0148_cross_correlation_ratio.tif', '20170806_0148_differential_phase.tif', '20170806_0148_differential_reflectivity.tif', '20170806_0148_reflectivity.tif', '20170806_0148_spectrum_width.tif', '20170806_0148_velocity.tif']
# 20170806_0151
# ['20170806_0151_cross_correlation_ratio.tif', '20170806_0151_differential_phase.tif', '20170806_0151_differential_reflectivity.tif', '20170806_0151_reflectivity.tif', '20170806_0151_spectrum_width.tif', '20170806_0151_velocity.tif']
# ['20170806_0151_cross_correlation_ratio.tif', '20170806_0151_differential_phase.tif', '20170806_0151_differential_reflectivity.tif', '20170806_0151_reflectivity.tif', '20170806_0151_spectrum_width.tif', '20170806_0151_velocity.tif']
# 20170806_0154
# ['20170806_0154_cross_correlation_ratio.tif', '20170806_0154_differential_phase.tif', '20170806_0154_differential_reflectivity.tif', '20170806_0154_reflectivity.tif', '20170806_0154_spectrum_width.tif', '20170806_0154_velocity.tif']
# ['20170806_0154_cross_correlation_ratio.tif', '20170806_0154_differential_phase.tif', '20170806_0154_differential_reflectivity.tif', '20170806_0154_reflectivity.tif', '20170806_0154_spectrum_width.tif', '20170806_0154_velocity.tif']
# 20170806_0157
# ['20170806_0157_cross_correlation_ratio.tif', '20170806_0157_differential_phase.tif', '20170806_0157_differential_reflectivity.tif', '20170806_0157_reflectivity.tif', '20170806_0157_spectrum_width.tif', '20170806_0157_velocity.tif']
# ['20170806_0157_cross_correlation_ratio.tif', '20170806_0157_differential_phase.tif', '20170806_0157_differential_reflectivity.tif', '20170806_0157_reflectivity.tif', '20170806_0157_spectrum_width.tif', '20170806_0157_velocity.tif']
# 20170806_0200
# ['20170806_0200_cross_correlation_ratio.tif', '20170806_0200_differential_phase.tif', '20170806_0200_differential_reflectivity.tif', '20170806_0200_reflectivity.tif', '20170806_0200_spectrum_width.tif', '20170806_0200_velocity.tif']
# ['20170806_0200_cross_correlation_ratio.tif', '20170806_0200_differential_phase.tif', '20170806_0200_differential_reflectivity.tif', '20170806_0200_reflectivity.tif', '20170806_0200_spectrum_width.tif', '20170806_0200_velocity.tif']
# 20170806_0204
# ['20170806_0204_cross_correlation_ratio.tif', '20170806_0204_differential_phase.tif', '20170806_0204_differential_reflectivity.tif', '20170806_0204_reflectivity.tif', '20170806_0204_spectrum_width.tif', '20170806_0204_velocity.tif']
# ['20170806_0204_cross_correlation_ratio.tif', '20170806_0204_differential_phase.tif', '20170806_0204_differential_reflectivity.tif', '20170806_0204_reflectivity.tif', '20170806_0204_spectrum_width.tif', '20170806_0204_velocity.tif']
# 20170806_0208
# ['20170806_0208_cross_correlation_ratio.tif', '20170806_0208_differential_phase.tif', '20170806_0208_differential_reflectivity.tif', '20170806_0208_reflectivity.tif', '20170806_0208_spectrum_width.tif', '20170806_0208_velocity.tif']
# ['20170806_0208_cross_correlation_ratio.tif', '20170806_0208_differential_phase.tif', '20170806_0208_differential_reflectivity.tif', '20170806_0208_reflectivity.tif', '20170806_0208_spectrum_width.tif', '20170806_0208_velocity.tif']
# 20170806_0211
# ['20170806_0211_cross_correlation_ratio.tif', '20170806_0211_differential_phase.tif', '20170806_0211_differential_reflectivity.tif', '20170806_0211_reflectivity.tif', '20170806_0211_spectrum_width.tif', '20170806_0211_velocity.tif']
# ['20170806_0211_cross_correlation_ratio.tif', '20170806_0211_differential_phase.tif', '20170806_0211_differential_reflectivity.tif', '20170806_0211_reflectivity.tif', '20170806_0211_spectrum_width.tif', '20170806_0211_velocity.tif']
# 20170806_0214
# ['20170806_0214_cross_correlation_ratio.tif', '20170806_0214_differential_phase.tif', '20170806_0214_differential_reflectivity.tif', '20170806_0214_reflectivity.tif', '20170806_0214_spectrum_width.tif', '20170806_0214_velocity.tif']
# ['20170806_0214_cross_correlation_ratio.tif', '20170806_0214_differential_phase.tif', '20170806_0214_differential_reflectivity.tif', '20170806_0214_reflectivity.tif', '20170806_0214_spectrum_width.tif', '20170806_0214_velocity.tif']
# 20170806_0218
# ['20170806_0218_cross_correlation_ratio.tif', '20170806_0218_differential_phase.tif', '20170806_0218_differential_reflectivity.tif', '20170806_0218_reflectivity.tif', '20170806_0218_spectrum_width.tif', '20170806_0218_velocity.tif']
# ['20170806_0218_cross_correlation_ratio.tif', '20170806_0218_differential_phase.tif', '20170806_0218_differential_reflectivity.tif', '20170806_0218_reflectivity.tif', '20170806_0218_spectrum_width.tif', '20170806_0218_velocity.tif']
# 20170806_0222
# ['20170806_0222_cross_correlation_ratio.tif', '20170806_0222_differential_phase.tif', '20170806_0222_differential_reflectivity.tif', '20170806_0222_reflectivity.tif', '20170806_0222_spectrum_width.tif', '20170806_0222_velocity.tif']
# ['20170806_0222_cross_correlation_ratio.tif', '20170806_0222_differential_phase.tif', '20170806_0222_differential_reflectivity.tif', '20170806_0222_reflectivity.tif', '20170806_0222_spectrum_width.tif', '20170806_0222_velocity.tif']
# 20170806_0226
# ['20170806_0226_cross_correlation_ratio.tif', '20170806_0226_differential_phase.tif', '20170806_0226_differential_reflectivity.tif', '20170806_0226_reflectivity.tif', '20170806_0226_spectrum_width.tif', '20170806_0226_velocity.tif']
# ['20170806_0226_cross_correlation_ratio.tif', '20170806_0226_differential_phase.tif', '20170806_0226_differential_reflectivity.tif', '20170806_0226_reflectivity.tif', '20170806_0226_spectrum_width.tif', '20170806_0226_velocity.tif']
# 20170806_0230
# ['20170806_0230_cross_correlation_ratio.tif', '20170806_0230_differential_phase.tif', '20170806_0230_differential_reflectivity.tif', '20170806_0230_reflectivity.tif', '20170806_0230_spectrum_width.tif', '20170806_0230_velocity.tif']
# ['20170806_0230_cross_correlation_ratio.tif', '20170806_0230_differential_phase.tif', '20170806_0230_differential_reflectivity.tif', '20170806_0230_reflectivity.tif', '20170806_0230_spectrum_width.tif', '20170806_0230_velocity.tif']
# 20170806_0234
# ['20170806_0234_cross_correlation_ratio.tif', '20170806_0234_differential_phase.tif', '20170806_0234_differential_reflectivity.tif', '20170806_0234_reflectivity.tif', '20170806_0234_spectrum_width.tif', '20170806_0234_velocity.tif']
# ['20170806_0234_cross_correlation_ratio.tif', '20170806_0234_differential_phase.tif', '20170806_0234_differential_reflectivity.tif', '20170806_0234_reflectivity.tif', '20170806_0234_spectrum_width.tif', '20170806_0234_velocity.tif']
# 20170806_0238
# ['20170806_0238_cross_correlation_ratio.tif', '20170806_0238_differential_phase.tif', '20170806_0238_differential_reflectivity.tif', '20170806_0238_reflectivity.tif', '20170806_0238_spectrum_width.tif', '20170806_0238_velocity.tif']
# ['20170806_0238_cross_correlation_ratio.tif', '20170806_0238_differential_phase.tif', '20170806_0238_differential_reflectivity.tif', '20170806_0238_reflectivity.tif', '20170806_0238_spectrum_width.tif', '20170806_0238_velocity.tif']
# 20170806_0242
# ['20170806_0242_cross_correlation_ratio.tif', '20170806_0242_differential_phase.tif', '20170806_0242_differential_reflectivity.tif', '20170806_0242_reflectivity.tif', '20170806_0242_spectrum_width.tif', '20170806_0242_velocity.tif']
# ['20170806_0242_cross_correlation_ratio.tif', '20170806_0242_differential_phase.tif', '20170806_0242_differential_reflectivity.tif', '20170806_0242_reflectivity.tif', '20170806_0242_spectrum_width.tif', '20170806_0242_velocity.tif']
# 20170806_0246
# ['20170806_0246_cross_correlation_ratio.tif', '20170806_0246_differential_phase.tif', '20170806_0246_differential_reflectivity.tif', '20170806_0246_reflectivity.tif', '20170806_0246_spectrum_width.tif', '20170806_0246_velocity.tif']
# ['20170806_0246_cross_correlation_ratio.tif', '20170806_0246_differential_phase.tif', '20170806_0246_differential_reflectivity.tif', '20170806_0246_reflectivity.tif', '20170806_0246_spectrum_width.tif', '20170806_0246_velocity.tif']
# 20170806_0250
# ['20170806_0250_cross_correlation_ratio.tif', '20170806_0250_differential_phase.tif', '20170806_0250_differential_reflectivity.tif', '20170806_0250_reflectivity.tif', '20170806_0250_spectrum_width.tif', '20170806_0250_velocity.tif']
# ['20170806_0250_cross_correlation_ratio.tif', '20170806_0250_differential_phase.tif', '20170806_0250_differential_reflectivity.tif', '20170806_0250_reflectivity.tif', '20170806_0250_spectrum_width.tif', '20170806_0250_velocity.tif']
# 20170806_0253
# ['20170806_0253_cross_correlation_ratio.tif', '20170806_0253_differential_phase.tif', '20170806_0253_differential_reflectivity.tif', '20170806_0253_reflectivity.tif', '20170806_0253_spectrum_width.tif', '20170806_0253_velocity.tif']
# ['20170806_0253_cross_correlation_ratio.tif', '20170806_0253_differential_phase.tif', '20170806_0253_differential_reflectivity.tif', '20170806_0253_reflectivity.tif', '20170806_0253_spectrum_width.tif', '20170806_0253_velocity.tif']
# 20170806_0257
# ['20170806_0257_cross_correlation_ratio.tif', '20170806_0257_differential_phase.tif', '20170806_0257_differential_reflectivity.tif', '20170806_0257_reflectivity.tif', '20170806_0257_spectrum_width.tif', '20170806_0257_velocity.tif']
# ['20170806_0257_cross_correlation_ratio.tif', '20170806_0257_differential_phase.tif', '20170806_0257_differential_reflectivity.tif', '20170806_0257_reflectivity.tif', '20170806_0257_spectrum_width.tif', '20170806_0257_velocity.tif']
# 20170806_0301
# ['20170806_0301_cross_correlation_ratio.tif', '20170806_0301_differential_phase.tif', '20170806_0301_differential_reflectivity.tif', '20170806_0301_reflectivity.tif', '20170806_0301_spectrum_width.tif', '20170806_0301_velocity.tif']
# ['20170806_0301_cross_correlation_ratio.tif', '20170806_0301_differential_phase.tif', '20170806_0301_differential_reflectivity.tif', '20170806_0301_reflectivity.tif', '20170806_0301_spectrum_width.tif', '20170806_0301_velocity.tif']
# 20170806_0305
# ['20170806_0305_cross_correlation_ratio.tif', '20170806_0305_differential_phase.tif', '20170806_0305_differential_reflectivity.tif', '20170806_0305_reflectivity.tif', '20170806_0305_spectrum_width.tif', '20170806_0305_velocity.tif']
# ['20170806_0305_cross_correlation_ratio.tif', '20170806_0305_differential_phase.tif', '20170806_0305_differential_reflectivity.tif', '20170806_0305_reflectivity.tif', '20170806_0305_spectrum_width.tif', '20170806_0305_velocity.tif']
# 20170806_0309
# ['20170806_0309_cross_correlation_ratio.tif', '20170806_0309_differential_phase.tif', '20170806_0309_differential_reflectivity.tif', '20170806_0309_reflectivity.tif', '20170806_0309_spectrum_width.tif', '20170806_0309_velocity.tif']
# ['20170806_0309_cross_correlation_ratio.tif', '20170806_0309_differential_phase.tif', '20170806_0309_differential_reflectivity.tif', '20170806_0309_reflectivity.tif', '20170806_0309_spectrum_width.tif', '20170806_0309_velocity.tif']
# 20170806_0313
# ['20170806_0313_cross_correlation_ratio.tif', '20170806_0313_differential_phase.tif', '20170806_0313_differential_reflectivity.tif', '20170806_0313_reflectivity.tif', '20170806_0313_spectrum_width.tif', '20170806_0313_velocity.tif']
# ['20170806_0313_cross_correlation_ratio.tif', '20170806_0313_differential_phase.tif', '20170806_0313_differential_reflectivity.tif', '20170806_0313_reflectivity.tif', '20170806_0313_spectrum_width.tif', '20170806_0313_velocity.tif']
# 20170806_0317
# ['20170806_0317_cross_correlation_ratio.tif', '20170806_0317_differential_phase.tif', '20170806_0317_differential_reflectivity.tif', '20170806_0317_reflectivity.tif', '20170806_0317_spectrum_width.tif', '20170806_0317_velocity.tif']
# ['20170806_0317_cross_correlation_ratio.tif', '20170806_0317_differential_phase.tif', '20170806_0317_differential_reflectivity.tif', '20170806_0317_reflectivity.tif', '20170806_0317_spectrum_width.tif', '20170806_0317_velocity.tif']
# 20170806_0320
# ['20170806_0320_cross_correlation_ratio.tif', '20170806_0320_differential_phase.tif', '20170806_0320_differential_reflectivity.tif', '20170806_0320_reflectivity.tif', '20170806_0320_spectrum_width.tif', '20170806_0320_velocity.tif']
# ['20170806_0320_cross_correlation_ratio.tif', '20170806_0320_differential_phase.tif', '20170806_0320_differential_reflectivity.tif', '20170806_0320_reflectivity.tif', '20170806_0320_spectrum_width.tif', '20170806_0320_velocity.tif']
# 20170806_0324
# ['20170806_0324_cross_correlation_ratio.tif', '20170806_0324_differential_phase.tif', '20170806_0324_differential_reflectivity.tif', '20170806_0324_reflectivity.tif', '20170806_0324_spectrum_width.tif', '20170806_0324_velocity.tif']
# ['20170806_0324_cross_correlation_ratio.tif', '20170806_0324_differential_phase.tif', '20170806_0324_differential_reflectivity.tif', '20170806_0324_reflectivity.tif', '20170806_0324_spectrum_width.tif', '20170806_0324_velocity.tif']
# 20170806_0328
# ['20170806_0328_cross_correlation_ratio.tif', '20170806_0328_differential_phase.tif', '20170806_0328_differential_reflectivity.tif', '20170806_0328_reflectivity.tif', '20170806_0328_spectrum_width.tif', '20170806_0328_velocity.tif']
# ['20170806_0328_cross_correlation_ratio.tif', '20170806_0328_differential_phase.tif', '20170806_0328_differential_reflectivity.tif', '20170806_0328_reflectivity.tif', '20170806_0328_spectrum_width.tif', '20170806_0328_velocity.tif']
# 20170806_0331
# ['20170806_0331_cross_correlation_ratio.tif', '20170806_0331_differential_phase.tif', '20170806_0331_differential_reflectivity.tif', '20170806_0331_reflectivity.tif', '20170806_0331_spectrum_width.tif', '20170806_0331_velocity.tif']
# ['20170806_0331_cross_correlation_ratio.tif', '20170806_0331_differential_phase.tif', '20170806_0331_differential_reflectivity.tif', '20170806_0331_reflectivity.tif', '20170806_0331_spectrum_width.tif', '20170806_0331_velocity.tif']
# 20170806_0335
# ['20170806_0335_cross_correlation_ratio.tif', '20170806_0335_differential_phase.tif', '20170806_0335_differential_reflectivity.tif', '20170806_0335_reflectivity.tif', '20170806_0335_spectrum_width.tif', '20170806_0335_velocity.tif']
# ['20170806_0335_cross_correlation_ratio.tif', '20170806_0335_differential_phase.tif', '20170806_0335_differential_reflectivity.tif', '20170806_0335_reflectivity.tif', '20170806_0335_spectrum_width.tif', '20170806_0335_velocity.tif']
# 20170806_0339
# ['20170806_0339_cross_correlation_ratio.tif', '20170806_0339_differential_phase.tif', '20170806_0339_differential_reflectivity.tif', '20170806_0339_reflectivity.tif', '20170806_0339_spectrum_width.tif', '20170806_0339_velocity.tif']
# ['20170806_0339_cross_correlation_ratio.tif', '20170806_0339_differential_phase.tif', '20170806_0339_differential_reflectivity.tif', '20170806_0339_reflectivity.tif', '20170806_0339_spectrum_width.tif', '20170806_0339_velocity.tif']
# 20170806_0342
# ['20170806_0342_cross_correlation_ratio.tif', '20170806_0342_differential_phase.tif', '20170806_0342_differential_reflectivity.tif', '20170806_0342_reflectivity.tif', '20170806_0342_spectrum_width.tif', '20170806_0342_velocity.tif']
# ['20170806_0342_cross_correlation_ratio.tif', '20170806_0342_differential_phase.tif', '20170806_0342_differential_reflectivity.tif', '20170806_0342_reflectivity.tif', '20170806_0342_spectrum_width.tif', '20170806_0342_velocity.tif']
# 20170806_0346
# ['20170806_0346_cross_correlation_ratio.tif', '20170806_0346_differential_phase.tif', '20170806_0346_differential_reflectivity.tif', '20170806_0346_reflectivity.tif', '20170806_0346_spectrum_width.tif', '20170806_0346_velocity.tif']
# ['20170806_0346_cross_correlation_ratio.tif', '20170806_0346_differential_phase.tif', '20170806_0346_differential_reflectivity.tif', '20170806_0346_reflectivity.tif', '20170806_0346_spectrum_width.tif', '20170806_0346_velocity.tif']
# 20170806_0349
# ['20170806_0349_cross_correlation_ratio.tif', '20170806_0349_differential_phase.tif', '20170806_0349_differential_reflectivity.tif', '20170806_0349_reflectivity.tif', '20170806_0349_spectrum_width.tif', '20170806_0349_velocity.tif']
# ['20170806_0349_cross_correlation_ratio.tif', '20170806_0349_differential_phase.tif', '20170806_0349_differential_reflectivity.tif', '20170806_0349_reflectivity.tif', '20170806_0349_spectrum_width.tif', '20170806_0349_velocity.tif']
# 20170806_0352
# ['20170806_0352_cross_correlation_ratio.tif', '20170806_0352_differential_phase.tif', '20170806_0352_differential_reflectivity.tif', '20170806_0352_reflectivity.tif', '20170806_0352_spectrum_width.tif', '20170806_0352_velocity.tif']
# ['20170806_0352_cross_correlation_ratio.tif', '20170806_0352_differential_phase.tif', '20170806_0352_differential_reflectivity.tif', '20170806_0352_reflectivity.tif', '20170806_0352_spectrum_width.tif', '20170806_0352_velocity.tif']
# Downloaded KEWX20170807_010342_V06
# Downloaded KEWX20170807_011249_V06
# Downloaded KEWX20170807_010645_V06
# Downloaded KEWX20170807_010040_V06
# Downloaded KEWX20170807_010947_V06
# Downloaded KEWX20170807_011558_V06
# Downloaded KEWX20170807_012507_V06
# Downloaded KEWX20170807_012205_V06
# Downloaded KEWX20170807_012809_V06
# Downloaded KEWX20170807_011902_V06
# Downloaded KEWX20170807_013112_V06
# Downloaded KEWX20170807_013722_V06
# Downloaded KEWX20170807_013414_V06
# Downloaded KEWX20170807_014336_V06
# Downloaded KEWX20170807_014638_V06
# Downloaded KEWX20170807_015242_V06
# Downloaded KEWX20170807_014030_V06
# Downloaded KEWX20170807_014940_V06
# Downloaded KEWX20170807_015847_V06
# Downloaded KEWX20170807_015545_V06
# Downloaded KEWX20170807_020232_V06
# Downloaded KEWX20170807_021319_V06
# Downloaded KEWX20170807_020619_V06
# Downloaded KEWX20170807_020949_V06
# Downloaded KEWX20170807_022020_V06
# Downloaded KEWX20170807_021650_V06
# Downloaded KEWX20170807_022336_V06
# Downloaded KEWX20170807_022653_V06
# Downloaded KEWX20170807_023009_V06
# Downloaded KEWX20170807_024524_V06
# Downloaded KEWX20170807_023739_V06
# Downloaded KEWX20170807_023354_V06
# Downloaded KEWX20170807_024125_V06
# Downloaded KEWX20170807_025337_V06
# Downloaded KEWX20170807_031048_V06
# Downloaded KEWX20170807_030635_V06
# Downloaded KEWX20170807_024937_V06
# Downloaded KEWX20170807_030206_V06
# Downloaded KEWX20170807_025752_V06
# Downloaded KEWX20170807_031517_V06
# Downloaded KEWX20170807_032843_V06
# Downloaded KEWX20170807_032414_V06
# Downloaded KEWX20170807_031944_V06
# Downloaded KEWX20170807_033311_V06
# Downloaded KEWX20170807_033739_V06
# Downloaded KEWX20170807_035532_V06
# Downloaded KEWX20170807_035102_V06
# Downloaded KEWX20170807_034207_V06
# Downloaded KEWX20170807_034635_V06
# Downloaded KEWX20170807_035959_V06
# 50 out of 50 files downloaded...0 errors
# 20170807_0100
# ['20170807_0100_cross_correlation_ratio.tif', '20170807_0100_differential_phase.tif', '20170807_0100_differential_reflectivity.tif', '20170807_0100_reflectivity.tif', '20170807_0100_spectrum_width.tif', '20170807_0100_velocity.tif']
# ['20170807_0100_cross_correlation_ratio.tif', '20170807_0100_differential_phase.tif', '20170807_0100_differential_reflectivity.tif', '20170807_0100_reflectivity.tif', '20170807_0100_spectrum_width.tif', '20170807_0100_velocity.tif']
# 20170807_0103
# ['20170807_0103_cross_correlation_ratio.tif', '20170807_0103_differential_phase.tif', '20170807_0103_differential_reflectivity.tif', '20170807_0103_reflectivity.tif', '20170807_0103_spectrum_width.tif', '20170807_0103_velocity.tif']
# ['20170807_0103_cross_correlation_ratio.tif', '20170807_0103_differential_phase.tif', '20170807_0103_differential_reflectivity.tif', '20170807_0103_reflectivity.tif', '20170807_0103_spectrum_width.tif', '20170807_0103_velocity.tif']
# 20170807_0106
# ['20170807_0106_cross_correlation_ratio.tif', '20170807_0106_differential_phase.tif', '20170807_0106_differential_reflectivity.tif', '20170807_0106_reflectivity.tif', '20170807_0106_spectrum_width.tif', '20170807_0106_velocity.tif']
# ['20170807_0106_cross_correlation_ratio.tif', '20170807_0106_differential_phase.tif', '20170807_0106_differential_reflectivity.tif', '20170807_0106_reflectivity.tif', '20170807_0106_spectrum_width.tif', '20170807_0106_velocity.tif']
# 20170807_0109
# ['20170807_0109_cross_correlation_ratio.tif', '20170807_0109_differential_phase.tif', '20170807_0109_differential_reflectivity.tif', '20170807_0109_reflectivity.tif', '20170807_0109_spectrum_width.tif', '20170807_0109_velocity.tif']
# ['20170807_0109_cross_correlation_ratio.tif', '20170807_0109_differential_phase.tif', '20170807_0109_differential_reflectivity.tif', '20170807_0109_reflectivity.tif', '20170807_0109_spectrum_width.tif', '20170807_0109_velocity.tif']
# 20170807_0112
# ['20170807_0112_cross_correlation_ratio.tif', '20170807_0112_differential_phase.tif', '20170807_0112_differential_reflectivity.tif', '20170807_0112_reflectivity.tif', '20170807_0112_spectrum_width.tif', '20170807_0112_velocity.tif']
# ['20170807_0112_cross_correlation_ratio.tif', '20170807_0112_differential_phase.tif', '20170807_0112_differential_reflectivity.tif', '20170807_0112_reflectivity.tif', '20170807_0112_spectrum_width.tif', '20170807_0112_velocity.tif']
# 20170807_0115
# ['20170807_0115_cross_correlation_ratio.tif', '20170807_0115_differential_phase.tif', '20170807_0115_differential_reflectivity.tif', '20170807_0115_reflectivity.tif', '20170807_0115_spectrum_width.tif', '20170807_0115_velocity.tif']
# ['20170807_0115_cross_correlation_ratio.tif', '20170807_0115_differential_phase.tif', '20170807_0115_differential_reflectivity.tif', '20170807_0115_reflectivity.tif', '20170807_0115_spectrum_width.tif', '20170807_0115_velocity.tif']
# 20170807_0119
# ['20170807_0119_cross_correlation_ratio.tif', '20170807_0119_differential_phase.tif', '20170807_0119_differential_reflectivity.tif', '20170807_0119_reflectivity.tif', '20170807_0119_spectrum_width.tif', '20170807_0119_velocity.tif']
# ['20170807_0119_cross_correlation_ratio.tif', '20170807_0119_differential_phase.tif', '20170807_0119_differential_reflectivity.tif', '20170807_0119_reflectivity.tif', '20170807_0119_spectrum_width.tif', '20170807_0119_velocity.tif']
# 20170807_0122
# ['20170807_0122_cross_correlation_ratio.tif', '20170807_0122_differential_phase.tif', '20170807_0122_differential_reflectivity.tif', '20170807_0122_reflectivity.tif', '20170807_0122_spectrum_width.tif', '20170807_0122_velocity.tif']
# ['20170807_0122_cross_correlation_ratio.tif', '20170807_0122_differential_phase.tif', '20170807_0122_differential_reflectivity.tif', '20170807_0122_reflectivity.tif', '20170807_0122_spectrum_width.tif', '20170807_0122_velocity.tif']
# 20170807_0125
# ['20170807_0125_cross_correlation_ratio.tif', '20170807_0125_differential_phase.tif', '20170807_0125_differential_reflectivity.tif', '20170807_0125_reflectivity.tif', '20170807_0125_spectrum_width.tif', '20170807_0125_velocity.tif']
# ['20170807_0125_cross_correlation_ratio.tif', '20170807_0125_differential_phase.tif', '20170807_0125_differential_reflectivity.tif', '20170807_0125_reflectivity.tif', '20170807_0125_spectrum_width.tif', '20170807_0125_velocity.tif']
# 20170807_0128
# ['20170807_0128_cross_correlation_ratio.tif', '20170807_0128_differential_phase.tif', '20170807_0128_differential_reflectivity.tif', '20170807_0128_reflectivity.tif', '20170807_0128_spectrum_width.tif', '20170807_0128_velocity.tif']
# ['20170807_0128_cross_correlation_ratio.tif', '20170807_0128_differential_phase.tif', '20170807_0128_differential_reflectivity.tif', '20170807_0128_reflectivity.tif', '20170807_0128_spectrum_width.tif', '20170807_0128_velocity.tif']
# 20170807_0131
# ['20170807_0131_cross_correlation_ratio.tif', '20170807_0131_differential_phase.tif', '20170807_0131_differential_reflectivity.tif', '20170807_0131_reflectivity.tif', '20170807_0131_spectrum_width.tif', '20170807_0131_velocity.tif']
# ['20170807_0131_cross_correlation_ratio.tif', '20170807_0131_differential_phase.tif', '20170807_0131_differential_reflectivity.tif', '20170807_0131_reflectivity.tif', '20170807_0131_spectrum_width.tif', '20170807_0131_velocity.tif']
# 20170807_0134
# ['20170807_0134_cross_correlation_ratio.tif', '20170807_0134_differential_phase.tif', '20170807_0134_differential_reflectivity.tif', '20170807_0134_reflectivity.tif', '20170807_0134_spectrum_width.tif', '20170807_0134_velocity.tif']
# ['20170807_0134_cross_correlation_ratio.tif', '20170807_0134_differential_phase.tif', '20170807_0134_differential_reflectivity.tif', '20170807_0134_reflectivity.tif', '20170807_0134_spectrum_width.tif', '20170807_0134_velocity.tif']
# 20170807_0137
# ['20170807_0137_cross_correlation_ratio.tif', '20170807_0137_differential_phase.tif', '20170807_0137_differential_reflectivity.tif', '20170807_0137_reflectivity.tif', '20170807_0137_spectrum_width.tif', '20170807_0137_velocity.tif']
# ['20170807_0137_cross_correlation_ratio.tif', '20170807_0137_differential_phase.tif', '20170807_0137_differential_reflectivity.tif', '20170807_0137_reflectivity.tif', '20170807_0137_spectrum_width.tif', '20170807_0137_velocity.tif']
# 20170807_0140
# ['20170807_0140_cross_correlation_ratio.tif', '20170807_0140_differential_phase.tif', '20170807_0140_differential_reflectivity.tif', '20170807_0140_reflectivity.tif', '20170807_0140_spectrum_width.tif', '20170807_0140_velocity.tif']
# ['20170807_0140_cross_correlation_ratio.tif', '20170807_0140_differential_phase.tif', '20170807_0140_differential_reflectivity.tif', '20170807_0140_reflectivity.tif', '20170807_0140_spectrum_width.tif', '20170807_0140_velocity.tif']
# 20170807_0143
# ['20170807_0143_cross_correlation_ratio.tif', '20170807_0143_differential_phase.tif', '20170807_0143_differential_reflectivity.tif', '20170807_0143_reflectivity.tif', '20170807_0143_spectrum_width.tif', '20170807_0143_velocity.tif']
# ['20170807_0143_cross_correlation_ratio.tif', '20170807_0143_differential_phase.tif', '20170807_0143_differential_reflectivity.tif', '20170807_0143_reflectivity.tif', '20170807_0143_spectrum_width.tif', '20170807_0143_velocity.tif']
# 20170807_0146
# ['20170807_0146_cross_correlation_ratio.tif', '20170807_0146_differential_phase.tif', '20170807_0146_differential_reflectivity.tif', '20170807_0146_reflectivity.tif', '20170807_0146_spectrum_width.tif', '20170807_0146_velocity.tif']
# ['20170807_0146_cross_correlation_ratio.tif', '20170807_0146_differential_phase.tif', '20170807_0146_differential_reflectivity.tif', '20170807_0146_reflectivity.tif', '20170807_0146_spectrum_width.tif', '20170807_0146_velocity.tif']
# 20170807_0149
# ['20170807_0149_cross_correlation_ratio.tif', '20170807_0149_differential_phase.tif', '20170807_0149_differential_reflectivity.tif', '20170807_0149_reflectivity.tif', '20170807_0149_spectrum_width.tif', '20170807_0149_velocity.tif']
# ['20170807_0149_cross_correlation_ratio.tif', '20170807_0149_differential_phase.tif', '20170807_0149_differential_reflectivity.tif', '20170807_0149_reflectivity.tif', '20170807_0149_spectrum_width.tif', '20170807_0149_velocity.tif']
# 20170807_0152
# ['20170807_0152_cross_correlation_ratio.tif', '20170807_0152_differential_phase.tif', '20170807_0152_differential_reflectivity.tif', '20170807_0152_reflectivity.tif', '20170807_0152_spectrum_width.tif', '20170807_0152_velocity.tif']
# ['20170807_0152_cross_correlation_ratio.tif', '20170807_0152_differential_phase.tif', '20170807_0152_differential_reflectivity.tif', '20170807_0152_reflectivity.tif', '20170807_0152_spectrum_width.tif', '20170807_0152_velocity.tif']
# 20170807_0155
# ['20170807_0155_cross_correlation_ratio.tif', '20170807_0155_differential_phase.tif', '20170807_0155_differential_reflectivity.tif', '20170807_0155_reflectivity.tif', '20170807_0155_spectrum_width.tif', '20170807_0155_velocity.tif']
# ['20170807_0155_cross_correlation_ratio.tif', '20170807_0155_differential_phase.tif', '20170807_0155_differential_reflectivity.tif', '20170807_0155_reflectivity.tif', '20170807_0155_spectrum_width.tif', '20170807_0155_velocity.tif']
# 20170807_0158
# ['20170807_0158_cross_correlation_ratio.tif', '20170807_0158_differential_phase.tif', '20170807_0158_differential_reflectivity.tif', '20170807_0158_reflectivity.tif', '20170807_0158_spectrum_width.tif', '20170807_0158_velocity.tif']
# ['20170807_0158_cross_correlation_ratio.tif', '20170807_0158_differential_phase.tif', '20170807_0158_differential_reflectivity.tif', '20170807_0158_reflectivity.tif', '20170807_0158_spectrum_width.tif', '20170807_0158_velocity.tif']
# 20170807_0202
# ['20170807_0202_cross_correlation_ratio.tif', '20170807_0202_differential_phase.tif', '20170807_0202_differential_reflectivity.tif', '20170807_0202_reflectivity.tif', '20170807_0202_spectrum_width.tif', '20170807_0202_velocity.tif']
# ['20170807_0202_cross_correlation_ratio.tif', '20170807_0202_differential_phase.tif', '20170807_0202_differential_reflectivity.tif', '20170807_0202_reflectivity.tif', '20170807_0202_spectrum_width.tif', '20170807_0202_velocity.tif']
# 20170807_0206
# ['20170807_0206_cross_correlation_ratio.tif', '20170807_0206_differential_phase.tif', '20170807_0206_differential_reflectivity.tif', '20170807_0206_reflectivity.tif', '20170807_0206_spectrum_width.tif', '20170807_0206_velocity.tif']
# ['20170807_0206_cross_correlation_ratio.tif', '20170807_0206_differential_phase.tif', '20170807_0206_differential_reflectivity.tif', '20170807_0206_reflectivity.tif', '20170807_0206_spectrum_width.tif', '20170807_0206_velocity.tif']
# 20170807_0209
# ['20170807_0209_cross_correlation_ratio.tif', '20170807_0209_differential_phase.tif', '20170807_0209_differential_reflectivity.tif', '20170807_0209_reflectivity.tif', '20170807_0209_spectrum_width.tif', '20170807_0209_velocity.tif']
# ['20170807_0209_cross_correlation_ratio.tif', '20170807_0209_differential_phase.tif', '20170807_0209_differential_reflectivity.tif', '20170807_0209_reflectivity.tif', '20170807_0209_spectrum_width.tif', '20170807_0209_velocity.tif']
# 20170807_0213
# ['20170807_0213_cross_correlation_ratio.tif', '20170807_0213_differential_phase.tif', '20170807_0213_differential_reflectivity.tif', '20170807_0213_reflectivity.tif', '20170807_0213_spectrum_width.tif', '20170807_0213_velocity.tif']
# ['20170807_0213_cross_correlation_ratio.tif', '20170807_0213_differential_phase.tif', '20170807_0213_differential_reflectivity.tif', '20170807_0213_reflectivity.tif', '20170807_0213_spectrum_width.tif', '20170807_0213_velocity.tif']
# 20170807_0216
# ['20170807_0216_cross_correlation_ratio.tif', '20170807_0216_differential_phase.tif', '20170807_0216_differential_reflectivity.tif', '20170807_0216_reflectivity.tif', '20170807_0216_spectrum_width.tif', '20170807_0216_velocity.tif']
# ['20170807_0216_cross_correlation_ratio.tif', '20170807_0216_differential_phase.tif', '20170807_0216_differential_reflectivity.tif', '20170807_0216_reflectivity.tif', '20170807_0216_spectrum_width.tif', '20170807_0216_velocity.tif']
# 20170807_0220
# ['20170807_0220_cross_correlation_ratio.tif', '20170807_0220_differential_phase.tif', '20170807_0220_differential_reflectivity.tif', '20170807_0220_reflectivity.tif', '20170807_0220_spectrum_width.tif', '20170807_0220_velocity.tif']
# ['20170807_0220_cross_correlation_ratio.tif', '20170807_0220_differential_phase.tif', '20170807_0220_differential_reflectivity.tif', '20170807_0220_reflectivity.tif', '20170807_0220_spectrum_width.tif', '20170807_0220_velocity.tif']
# 20170807_0223
# ['20170807_0223_cross_correlation_ratio.tif', '20170807_0223_differential_phase.tif', '20170807_0223_differential_reflectivity.tif', '20170807_0223_reflectivity.tif', '20170807_0223_spectrum_width.tif', '20170807_0223_velocity.tif']
# ['20170807_0223_cross_correlation_ratio.tif', '20170807_0223_differential_phase.tif', '20170807_0223_differential_reflectivity.tif', '20170807_0223_reflectivity.tif', '20170807_0223_spectrum_width.tif', '20170807_0223_velocity.tif']
# 20170807_0226
# ['20170807_0226_cross_correlation_ratio.tif', '20170807_0226_differential_phase.tif', '20170807_0226_differential_reflectivity.tif', '20170807_0226_reflectivity.tif', '20170807_0226_spectrum_width.tif', '20170807_0226_velocity.tif']
# ['20170807_0226_cross_correlation_ratio.tif', '20170807_0226_differential_phase.tif', '20170807_0226_differential_reflectivity.tif', '20170807_0226_reflectivity.tif', '20170807_0226_spectrum_width.tif', '20170807_0226_velocity.tif']
# 20170807_0230
# ['20170807_0230_cross_correlation_ratio.tif', '20170807_0230_differential_phase.tif', '20170807_0230_differential_reflectivity.tif', '20170807_0230_reflectivity.tif', '20170807_0230_spectrum_width.tif', '20170807_0230_velocity.tif']
# ['20170807_0230_cross_correlation_ratio.tif', '20170807_0230_differential_phase.tif', '20170807_0230_differential_reflectivity.tif', '20170807_0230_reflectivity.tif', '20170807_0230_spectrum_width.tif', '20170807_0230_velocity.tif']
# 20170807_0233
# ['20170807_0233_cross_correlation_ratio.tif', '20170807_0233_differential_phase.tif', '20170807_0233_differential_reflectivity.tif', '20170807_0233_reflectivity.tif', '20170807_0233_spectrum_width.tif', '20170807_0233_velocity.tif']
# ['20170807_0233_cross_correlation_ratio.tif', '20170807_0233_differential_phase.tif', '20170807_0233_differential_reflectivity.tif', '20170807_0233_reflectivity.tif', '20170807_0233_spectrum_width.tif', '20170807_0233_velocity.tif']
# 20170807_0237
# ['20170807_0237_cross_correlation_ratio.tif', '20170807_0237_differential_phase.tif', '20170807_0237_differential_reflectivity.tif', '20170807_0237_reflectivity.tif', '20170807_0237_spectrum_width.tif', '20170807_0237_velocity.tif']
# ['20170807_0237_cross_correlation_ratio.tif', '20170807_0237_differential_phase.tif', '20170807_0237_differential_reflectivity.tif', '20170807_0237_reflectivity.tif', '20170807_0237_spectrum_width.tif', '20170807_0237_velocity.tif']
# 20170807_0241
# ['20170807_0241_cross_correlation_ratio.tif', '20170807_0241_differential_phase.tif', '20170807_0241_differential_reflectivity.tif', '20170807_0241_reflectivity.tif', '20170807_0241_spectrum_width.tif', '20170807_0241_velocity.tif']
# ['20170807_0241_cross_correlation_ratio.tif', '20170807_0241_differential_phase.tif', '20170807_0241_differential_reflectivity.tif', '20170807_0241_reflectivity.tif', '20170807_0241_spectrum_width.tif', '20170807_0241_velocity.tif']
# 20170807_0245
# ['20170807_0245_cross_correlation_ratio.tif', '20170807_0245_differential_phase.tif', '20170807_0245_differential_reflectivity.tif', '20170807_0245_reflectivity.tif', '20170807_0245_spectrum_width.tif', '20170807_0245_velocity.tif']
# ['20170807_0245_cross_correlation_ratio.tif', '20170807_0245_differential_phase.tif', '20170807_0245_differential_reflectivity.tif', '20170807_0245_reflectivity.tif', '20170807_0245_spectrum_width.tif', '20170807_0245_velocity.tif']
# 20170807_0249
# ['20170807_0249_cross_correlation_ratio.tif', '20170807_0249_differential_phase.tif', '20170807_0249_differential_reflectivity.tif', '20170807_0249_reflectivity.tif', '20170807_0249_spectrum_width.tif', '20170807_0249_velocity.tif']
# ['20170807_0249_cross_correlation_ratio.tif', '20170807_0249_differential_phase.tif', '20170807_0249_differential_reflectivity.tif', '20170807_0249_reflectivity.tif', '20170807_0249_spectrum_width.tif', '20170807_0249_velocity.tif']
# 20170807_0253
# ['20170807_0253_cross_correlation_ratio.tif', '20170807_0253_differential_phase.tif', '20170807_0253_differential_reflectivity.tif', '20170807_0253_reflectivity.tif', '20170807_0253_spectrum_width.tif', '20170807_0253_velocity.tif']
# ['20170807_0253_cross_correlation_ratio.tif', '20170807_0253_differential_phase.tif', '20170807_0253_differential_reflectivity.tif', '20170807_0253_reflectivity.tif', '20170807_0253_spectrum_width.tif', '20170807_0253_velocity.tif']
# 20170807_0257
# ['20170807_0257_cross_correlation_ratio.tif', '20170807_0257_differential_phase.tif', '20170807_0257_differential_reflectivity.tif', '20170807_0257_reflectivity.tif', '20170807_0257_spectrum_width.tif', '20170807_0257_velocity.tif']
# ['20170807_0257_cross_correlation_ratio.tif', '20170807_0257_differential_phase.tif', '20170807_0257_differential_reflectivity.tif', '20170807_0257_reflectivity.tif', '20170807_0257_spectrum_width.tif', '20170807_0257_velocity.tif']
# 20170807_0302
# ['20170807_0302_cross_correlation_ratio.tif', '20170807_0302_differential_phase.tif', '20170807_0302_differential_reflectivity.tif', '20170807_0302_reflectivity.tif', '20170807_0302_spectrum_width.tif', '20170807_0302_velocity.tif']
# ['20170807_0302_cross_correlation_ratio.tif', '20170807_0302_differential_phase.tif', '20170807_0302_differential_reflectivity.tif', '20170807_0302_reflectivity.tif', '20170807_0302_spectrum_width.tif', '20170807_0302_velocity.tif']
# 20170807_0306
# ['20170807_0306_cross_correlation_ratio.tif', '20170807_0306_differential_phase.tif', '20170807_0306_differential_reflectivity.tif', '20170807_0306_reflectivity.tif', '20170807_0306_spectrum_width.tif', '20170807_0306_velocity.tif']
# ['20170807_0306_cross_correlation_ratio.tif', '20170807_0306_differential_phase.tif', '20170807_0306_differential_reflectivity.tif', '20170807_0306_reflectivity.tif', '20170807_0306_spectrum_width.tif', '20170807_0306_velocity.tif']
# 20170807_0310
# ['20170807_0310_cross_correlation_ratio.tif', '20170807_0310_differential_phase.tif', '20170807_0310_differential_reflectivity.tif', '20170807_0310_reflectivity.tif', '20170807_0310_spectrum_width.tif', '20170807_0310_velocity.tif']
# ['20170807_0310_cross_correlation_ratio.tif', '20170807_0310_differential_phase.tif', '20170807_0310_differential_reflectivity.tif', '20170807_0310_reflectivity.tif', '20170807_0310_spectrum_width.tif', '20170807_0310_velocity.tif']
# 20170807_0315
# ['20170807_0315_cross_correlation_ratio.tif', '20170807_0315_differential_phase.tif', '20170807_0315_differential_reflectivity.tif', '20170807_0315_reflectivity.tif', '20170807_0315_spectrum_width.tif', '20170807_0315_velocity.tif']
# ['20170807_0315_cross_correlation_ratio.tif', '20170807_0315_differential_phase.tif', '20170807_0315_differential_reflectivity.tif', '20170807_0315_reflectivity.tif', '20170807_0315_spectrum_width.tif', '20170807_0315_velocity.tif']
# 20170807_0319
# ['20170807_0319_cross_correlation_ratio.tif', '20170807_0319_differential_phase.tif', '20170807_0319_differential_reflectivity.tif', '20170807_0319_reflectivity.tif', '20170807_0319_spectrum_width.tif', '20170807_0319_velocity.tif']
# ['20170807_0319_cross_correlation_ratio.tif', '20170807_0319_differential_phase.tif', '20170807_0319_differential_reflectivity.tif', '20170807_0319_reflectivity.tif', '20170807_0319_spectrum_width.tif', '20170807_0319_velocity.tif']
# 20170807_0324
# ['20170807_0324_cross_correlation_ratio.tif', '20170807_0324_differential_phase.tif', '20170807_0324_differential_reflectivity.tif', '20170807_0324_reflectivity.tif', '20170807_0324_spectrum_width.tif', '20170807_0324_velocity.tif']
# ...
# 20170809_0129
# ['20170809_0129_cross_correlation_ratio.tif', '20170809_0129_differential_phase.tif', '20170809_0129_differential_reflectivity.tif', '20170809_0129_reflectivity.tif', '20170809_0129_spectrum_width.tif', '20170809_0129_velocity.tif']
# ['20170809_0129_cross_correlation_ratio.tif', '20170809_0129_differential_phase.tif', '20170809_0129_differential_reflectivity.tif', '20170809_0129_reflectivity.tif', '20170809_0129_spectrum_width.tif', '20170809_0129_velocity.tif']
# 20170809_0132
# ['20170809_0132_cross_correlation_ratio.tif', '20170809_0132_differential_phase.tif', '20170809_0132_differential_reflectivity.tif', '20170809_0132_reflectivity.tif', '20170809_0132_spectrum_width.tif', '20170809_0132_velocity.tif']
# ['20170809_0132_cross_correlation_ratio.tif', '20170809_0132_differential_phase.tif', '20170809_0132_differential_reflectivity.tif', '20170809_0132_reflectivity.tif', '20170809_0132_spectrum_width.tif', '20170809_0132_velocity.tif']
# 20170809_0135
# ['20170809_0135_cross_correlation_ratio.tif', '20170809_0135_differential_phase.tif', '20170809_0135_differential_reflectivity.tif', '20170809_0135_reflectivity.tif', '20170809_0135_spectrum_width.tif', '20170809_0135_velocity.tif']
# ['20170809_0135_cross_correlation_ratio.tif', '20170809_0135_differential_phase.tif', '20170809_0135_differential_reflectivity.tif', '20170809_0135_reflectivity.tif', '20170809_0135_spectrum_width.tif', '20170809_0135_velocity.tif']
# 20170809_0138
# ['20170809_0138_cross_correlation_ratio.tif', '20170809_0138_differential_phase.tif', '20170809_0138_differential_reflectivity.tif', '20170809_0138_reflectivity.tif', '20170809_0138_spectrum_width.tif', '20170809_0138_velocity.tif']
# ['20170809_0138_cross_correlation_ratio.tif', '20170809_0138_differential_phase.tif', '20170809_0138_differential_reflectivity.tif', '20170809_0138_reflectivity.tif', '20170809_0138_spectrum_width.tif', '20170809_0138_velocity.tif']
# 20170809_0141
# ['20170809_0141_cross_correlation_ratio.tif', '20170809_0141_differential_phase.tif', '20170809_0141_differential_reflectivity.tif', '20170809_0141_reflectivity.tif', '20170809_0141_spectrum_width.tif', '20170809_0141_velocity.tif']
# ['20170809_0141_cross_correlation_ratio.tif', '20170809_0141_differential_phase.tif', '20170809_0141_differential_reflectivity.tif', '20170809_0141_reflectivity.tif', '20170809_0141_spectrum_width.tif', '20170809_0141_velocity.tif']
# 20170809_0145
# ['20170809_0145_cross_correlation_ratio.tif', '20170809_0145_differential_phase.tif', '20170809_0145_differential_reflectivity.tif', '20170809_0145_reflectivity.tif', '20170809_0145_spectrum_width.tif', '20170809_0145_velocity.tif']
# ['20170809_0145_cross_correlation_ratio.tif', '20170809_0145_differential_phase.tif', '20170809_0145_differential_reflectivity.tif', '20170809_0145_reflectivity.tif', '20170809_0145_spectrum_width.tif', '20170809_0145_velocity.tif']
# 20170809_0148
# ['20170809_0148_cross_correlation_ratio.tif', '20170809_0148_differential_phase.tif', '20170809_0148_differential_reflectivity.tif', '20170809_0148_reflectivity.tif', '20170809_0148_spectrum_width.tif', '20170809_0148_velocity.tif']
# ['20170809_0148_cross_correlation_ratio.tif', '20170809_0148_differential_phase.tif', '20170809_0148_differential_reflectivity.tif', '20170809_0148_reflectivity.tif', '20170809_0148_spectrum_width.tif', '20170809_0148_velocity.tif']
# 20170809_0151
# ['20170809_0151_cross_correlation_ratio.tif', '20170809_0151_differential_phase.tif', '20170809_0151_differential_reflectivity.tif', '20170809_0151_reflectivity.tif', '20170809_0151_spectrum_width.tif', '20170809_0151_velocity.tif']
# ['20170809_0151_cross_correlation_ratio.tif', '20170809_0151_differential_phase.tif', '20170809_0151_differential_reflectivity.tif', '20170809_0151_reflectivity.tif', '20170809_0151_spectrum_width.tif', '20170809_0151_velocity.tif']
# 20170809_0154
# ['20170809_0154_cross_correlation_ratio.tif', '20170809_0154_differential_phase.tif', '20170809_0154_differential_reflectivity.tif', '20170809_0154_reflectivity.tif', '20170809_0154_spectrum_width.tif', '20170809_0154_velocity.tif']
# ['20170809_0154_cross_correlation_ratio.tif', '20170809_0154_differential_phase.tif', '20170809_0154_differential_reflectivity.tif', '20170809_0154_reflectivity.tif', '20170809_0154_spectrum_width.tif', '20170809_0154_velocity.tif']
# 20170809_0158
# ['20170809_0158_cross_correlation_ratio.tif', '20170809_0158_differential_phase.tif', '20170809_0158_differential_reflectivity.tif', '20170809_0158_reflectivity.tif', '20170809_0158_spectrum_width.tif', '20170809_0158_velocity.tif']
# ['20170809_0158_cross_correlation_ratio.tif', '20170809_0158_differential_phase.tif', '20170809_0158_differential_reflectivity.tif', '20170809_0158_reflectivity.tif', '20170809_0158_spectrum_width.tif', '20170809_0158_velocity.tif']
# 20170809_0201
# ['20170809_0201_cross_correlation_ratio.tif', '20170809_0201_differential_phase.tif', '20170809_0201_differential_reflectivity.tif', '20170809_0201_reflectivity.tif', '20170809_0201_spectrum_width.tif', '20170809_0201_velocity.tif']
# ['20170809_0201_cross_correlation_ratio.tif', '20170809_0201_differential_phase.tif', '20170809_0201_differential_reflectivity.tif', '20170809_0201_reflectivity.tif', '20170809_0201_spectrum_width.tif', '20170809_0201_velocity.tif']
# 20170809_0204
# ['20170809_0204_cross_correlation_ratio.tif', '20170809_0204_differential_phase.tif', '20170809_0204_differential_reflectivity.tif', '20170809_0204_reflectivity.tif', '20170809_0204_spectrum_width.tif', '20170809_0204_velocity.tif']
# ['20170809_0204_cross_correlation_ratio.tif', '20170809_0204_differential_phase.tif', '20170809_0204_differential_reflectivity.tif', '20170809_0204_reflectivity.tif', '20170809_0204_spectrum_width.tif', '20170809_0204_velocity.tif']
# 20170809_0208
# ['20170809_0208_cross_correlation_ratio.tif', '20170809_0208_differential_phase.tif', '20170809_0208_differential_reflectivity.tif', '20170809_0208_reflectivity.tif', '20170809_0208_spectrum_width.tif', '20170809_0208_velocity.tif']
# ['20170809_0208_cross_correlation_ratio.tif', '20170809_0208_differential_phase.tif', '20170809_0208_differential_reflectivity.tif', '20170809_0208_reflectivity.tif', '20170809_0208_spectrum_width.tif', '20170809_0208_velocity.tif']
# 20170809_0212
# ['20170809_0212_cross_correlation_ratio.tif', '20170809_0212_differential_phase.tif', '20170809_0212_differential_reflectivity.tif', '20170809_0212_reflectivity.tif', '20170809_0212_spectrum_width.tif', '20170809_0212_velocity.tif']
# ['20170809_0212_cross_correlation_ratio.tif', '20170809_0212_differential_phase.tif', '20170809_0212_differential_reflectivity.tif', '20170809_0212_reflectivity.tif', '20170809_0212_spectrum_width.tif', '20170809_0212_velocity.tif']
# 20170809_0216
# ['20170809_0216_cross_correlation_ratio.tif', '20170809_0216_differential_phase.tif', '20170809_0216_differential_reflectivity.tif', '20170809_0216_reflectivity.tif', '20170809_0216_spectrum_width.tif', '20170809_0216_velocity.tif']
# ['20170809_0216_cross_correlation_ratio.tif', '20170809_0216_differential_phase.tif', '20170809_0216_differential_reflectivity.tif', '20170809_0216_reflectivity.tif', '20170809_0216_spectrum_width.tif', '20170809_0216_velocity.tif']
# 20170809_0221
# ['20170809_0221_cross_correlation_ratio.tif', '20170809_0221_differential_phase.tif', '20170809_0221_differential_reflectivity.tif', '20170809_0221_reflectivity.tif', '20170809_0221_spectrum_width.tif', '20170809_0221_velocity.tif']
# ['20170809_0221_cross_correlation_ratio.tif', '20170809_0221_differential_phase.tif', '20170809_0221_differential_reflectivity.tif', '20170809_0221_reflectivity.tif', '20170809_0221_spectrum_width.tif', '20170809_0221_velocity.tif']
# 20170809_0225
# ['20170809_0225_cross_correlation_ratio.tif', '20170809_0225_differential_phase.tif', '20170809_0225_differential_reflectivity.tif', '20170809_0225_reflectivity.tif', '20170809_0225_spectrum_width.tif', '20170809_0225_velocity.tif']
# ['20170809_0225_cross_correlation_ratio.tif', '20170809_0225_differential_phase.tif', '20170809_0225_differential_reflectivity.tif', '20170809_0225_reflectivity.tif', '20170809_0225_spectrum_width.tif', '20170809_0225_velocity.tif']
# 20170809_0229
# ['20170809_0229_cross_correlation_ratio.tif', '20170809_0229_differential_phase.tif', '20170809_0229_differential_reflectivity.tif', '20170809_0229_reflectivity.tif', '20170809_0229_spectrum_width.tif', '20170809_0229_velocity.tif']
# ['20170809_0229_cross_correlation_ratio.tif', '20170809_0229_differential_phase.tif', '20170809_0229_differential_reflectivity.tif', '20170809_0229_reflectivity.tif', '20170809_0229_spectrum_width.tif', '20170809_0229_velocity.tif']
# 20170809_0233
# ['20170809_0233_cross_correlation_ratio.tif', '20170809_0233_differential_phase.tif', '20170809_0233_differential_reflectivity.tif', '20170809_0233_reflectivity.tif', '20170809_0233_spectrum_width.tif', '20170809_0233_velocity.tif']
# ['20170809_0233_cross_correlation_ratio.tif', '20170809_0233_differential_phase.tif', '20170809_0233_differential_reflectivity.tif', '20170809_0233_reflectivity.tif', '20170809_0233_spectrum_width.tif', '20170809_0233_velocity.tif']
# 20170809_0237
# ['20170809_0237_cross_correlation_ratio.tif', '20170809_0237_differential_phase.tif', '20170809_0237_differential_reflectivity.tif', '20170809_0237_reflectivity.tif', '20170809_0237_spectrum_width.tif', '20170809_0237_velocity.tif']
# ['20170809_0237_cross_correlation_ratio.tif', '20170809_0237_differential_phase.tif', '20170809_0237_differential_reflectivity.tif', '20170809_0237_reflectivity.tif', '20170809_0237_spectrum_width.tif', '20170809_0237_velocity.tif']
# 20170809_0241
# ['20170809_0241_cross_correlation_ratio.tif', '20170809_0241_differential_phase.tif', '20170809_0241_differential_reflectivity.tif', '20170809_0241_reflectivity.tif', '20170809_0241_spectrum_width.tif', '20170809_0241_velocity.tif']
# ['20170809_0241_cross_correlation_ratio.tif', '20170809_0241_differential_phase.tif', '20170809_0241_differential_reflectivity.tif', '20170809_0241_reflectivity.tif', '20170809_0241_spectrum_width.tif', '20170809_0241_velocity.tif']
# 20170809_0245
# ['20170809_0245_cross_correlation_ratio.tif', '20170809_0245_differential_phase.tif', '20170809_0245_differential_reflectivity.tif', '20170809_0245_reflectivity.tif', '20170809_0245_spectrum_width.tif', '20170809_0245_velocity.tif']
# ['20170809_0245_cross_correlation_ratio.tif', '20170809_0245_differential_phase.tif', '20170809_0245_differential_reflectivity.tif', '20170809_0245_reflectivity.tif', '20170809_0245_spectrum_width.tif', '20170809_0245_velocity.tif']
# 20170809_0249
# ['20170809_0249_cross_correlation_ratio.tif', '20170809_0249_differential_phase.tif', '20170809_0249_differential_reflectivity.tif', '20170809_0249_reflectivity.tif', '20170809_0249_spectrum_width.tif', '20170809_0249_velocity.tif']
# ['20170809_0249_cross_correlation_ratio.tif', '20170809_0249_differential_phase.tif', '20170809_0249_differential_reflectivity.tif', '20170809_0249_reflectivity.tif', '20170809_0249_spectrum_width.tif', '20170809_0249_velocity.tif']
# 20170809_0253
# ['20170809_0253_cross_correlation_ratio.tif', '20170809_0253_differential_phase.tif', '20170809_0253_differential_reflectivity.tif', '20170809_0253_reflectivity.tif', '20170809_0253_spectrum_width.tif', '20170809_0253_velocity.tif']
# ['20170809_0253_cross_correlation_ratio.tif', '20170809_0253_differential_phase.tif', '20170809_0253_differential_reflectivity.tif', '20170809_0253_reflectivity.tif', '20170809_0253_spectrum_width.tif', '20170809_0253_velocity.tif']
# 20170809_0256
# ['20170809_0256_cross_correlation_ratio.tif', '20170809_0256_differential_phase.tif', '20170809_0256_differential_reflectivity.tif', '20170809_0256_reflectivity.tif', '20170809_0256_spectrum_width.tif', '20170809_0256_velocity.tif']
# ['20170809_0256_cross_correlation_ratio.tif', '20170809_0256_differential_phase.tif', '20170809_0256_differential_reflectivity.tif', '20170809_0256_reflectivity.tif', '20170809_0256_spectrum_width.tif', '20170809_0256_velocity.tif']
# 20170809_0300
# ['20170809_0300_cross_correlation_ratio.tif', '20170809_0300_differential_phase.tif', '20170809_0300_differential_reflectivity.tif', '20170809_0300_reflectivity.tif', '20170809_0300_spectrum_width.tif', '20170809_0300_velocity.tif']
# ['20170809_0300_cross_correlation_ratio.tif', '20170809_0300_differential_phase.tif', '20170809_0300_differential_reflectivity.tif', '20170809_0300_reflectivity.tif', '20170809_0300_spectrum_width.tif', '20170809_0300_velocity.tif']
# 20170809_0304
# ['20170809_0304_cross_correlation_ratio.tif', '20170809_0304_differential_phase.tif', '20170809_0304_differential_reflectivity.tif', '20170809_0304_reflectivity.tif', '20170809_0304_spectrum_width.tif', '20170809_0304_velocity.tif']
# ['20170809_0304_cross_correlation_ratio.tif', '20170809_0304_differential_phase.tif', '20170809_0304_differential_reflectivity.tif', '20170809_0304_reflectivity.tif', '20170809_0304_spectrum_width.tif', '20170809_0304_velocity.tif']
# 20170809_0308
# ['20170809_0308_cross_correlation_ratio.tif', '20170809_0308_differential_phase.tif', '20170809_0308_differential_reflectivity.tif', '20170809_0308_reflectivity.tif', '20170809_0308_spectrum_width.tif', '20170809_0308_velocity.tif']
# ['20170809_0308_cross_correlation_ratio.tif', '20170809_0308_differential_phase.tif', '20170809_0308_differential_reflectivity.tif', '20170809_0308_reflectivity.tif', '20170809_0308_spectrum_width.tif', '20170809_0308_velocity.tif']
# 20170809_0312
# ['20170809_0312_cross_correlation_ratio.tif', '20170809_0312_differential_phase.tif', '20170809_0312_differential_reflectivity.tif', '20170809_0312_reflectivity.tif', '20170809_0312_spectrum_width.tif', '20170809_0312_velocity.tif']
# ['20170809_0312_cross_correlation_ratio.tif', '20170809_0312_differential_phase.tif', '20170809_0312_differential_reflectivity.tif', '20170809_0312_reflectivity.tif', '20170809_0312_spectrum_width.tif', '20170809_0312_velocity.tif']
# 20170809_0316
# ['20170809_0316_cross_correlation_ratio.tif', '20170809_0316_differential_phase.tif', '20170809_0316_differential_reflectivity.tif', '20170809_0316_reflectivity.tif', '20170809_0316_spectrum_width.tif', '20170809_0316_velocity.tif']
# ['20170809_0316_cross_correlation_ratio.tif', '20170809_0316_differential_phase.tif', '20170809_0316_differential_reflectivity.tif', '20170809_0316_reflectivity.tif', '20170809_0316_spectrum_width.tif', '20170809_0316_velocity.tif']
# 20170809_0320
# ['20170809_0320_cross_correlation_ratio.tif', '20170809_0320_differential_phase.tif', '20170809_0320_differential_reflectivity.tif', '20170809_0320_reflectivity.tif', '20170809_0320_spectrum_width.tif', '20170809_0320_velocity.tif']
# ['20170809_0320_cross_correlation_ratio.tif', '20170809_0320_differential_phase.tif', '20170809_0320_differential_reflectivity.tif', '20170809_0320_reflectivity.tif', '20170809_0320_spectrum_width.tif', '20170809_0320_velocity.tif']
# 20170809_0323
# ['20170809_0323_cross_correlation_ratio.tif', '20170809_0323_differential_phase.tif', '20170809_0323_differential_reflectivity.tif', '20170809_0323_reflectivity.tif', '20170809_0323_spectrum_width.tif', '20170809_0323_velocity.tif']
# ['20170809_0323_cross_correlation_ratio.tif', '20170809_0323_differential_phase.tif', '20170809_0323_differential_reflectivity.tif', '20170809_0323_reflectivity.tif', '20170809_0323_spectrum_width.tif', '20170809_0323_velocity.tif']
# 20170809_0327
# ['20170809_0327_cross_correlation_ratio.tif', '20170809_0327_differential_phase.tif', '20170809_0327_differential_reflectivity.tif', '20170809_0327_reflectivity.tif', '20170809_0327_spectrum_width.tif', '20170809_0327_velocity.tif']
# ['20170809_0327_cross_correlation_ratio.tif', '20170809_0327_differential_phase.tif', '20170809_0327_differential_reflectivity.tif', '20170809_0327_reflectivity.tif', '20170809_0327_spectrum_width.tif', '20170809_0327_velocity.tif']
